# %% [markdown]
# ## Model 7: Transfer Learning on ResNet50

# %% [markdown]
# ## Load modules

# %%
from keras.saving import load_model

import helpers
import importlib
importlib.reload(helpers)
# Out:
# <module 'helpers' from '/notebooks/helpers.py'>

# %% [markdown]
# ## Load model and test on image

# %%
# load best model
resnet50_input_shape = (244, 244)

model = load_model('models/resnet50_cifar10_240926_1615.keras', safe_mode=False)

# %%
# Run predictions on test images
image_folder = 'test_images'

class_mapping = {0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 
                 5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'}

target_size = (224, 224)  # Adjust according to your model's expected input size

helpers.predict_and_visualize(model, image_folder, target_size, class_mapping)
# Out:
# 1/1 [==============================] - 1s 656ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
